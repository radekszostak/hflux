# %%
import pandas

# %%
#load temp_osady_20220325.csv to pandas
df = pandas.read_csv('temp_osady_20220325.csv')
#convert "Timestamp" column to datetime
df['Timestamp'] = pandas.to_datetime(df['Timestamp'])

# %%
#plot T1, T2, T3, T4, T5, T6, T7, T8 columns fro df
df.plot(y=['T1','T2','T3','T4','T5','T6','T7','T8'])
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      Latitude  Longitude        Title Description           Timestamp   T1  \
# 0   50.935636  19.112739   Znacznik 1         NaN 2022-03-25 07:11:00  4.0
# 1   50.935710  19.112725   Znacznik 2         NaN 2022-03-25 07:16:00  3.0
# 2   50.935791  19.112714   Znacznik 3         NaN 2022-03-25 07:20:00  4.0
# 3   50.935870  19.112739   Znacznik 4          Lo 2022-03-25 07:29:00  2.9
# 4   50.935940  19.112756   Znacznik 5         NaN 2022-03-25 07:33:00  3.9
# 5   50.935980  19.112751   Znacznik 6         NaN 2022-03-25 07:36:00  4.1
# 6   50.936034  19.112749   Znacznik 7         NaN 2022-03-25 07:38:00  3.9
# 7   50.936101  19.112777   Znacznik 8         NaN 2022-03-25 07:41:00  2.9
# 8   50.936193  19.112863   Znacznik 9         NaN 2022-03-25 07:43:00  5.4
# 9   50.936253  19.112892  Znacznik 10         NaN 2022-03-25 07:45:00  4.5
# 10  50.936321  19.112970  Znacznik 11         NaN 2022-03-25 07:47:00  2.9
# ...
